# %% [markdown]
# # Exploratory Data Analysis
#
# Milestone 2: load the dataset and get a feel for it before modeling.
# Look at distributions, missing values, and correlations with the target.

# %%
import sys
sys.path.append('..')

from src.load_data import load_dataset

df = load_dataset()
print(df.shape)
df.head()

# %% [markdown]
# ## Quick checks
#
# TODO: explore the data. Some starting points are below.

# %%
# Missing values per column
df.isna().sum()

# TODO: plot distributions, e.g. df.hist(figsize=(12, 8))
# TODO: inspect correlations, e.g. df.corr(numeric_only=True)
# TODO: identify your target column and the most predictive features
